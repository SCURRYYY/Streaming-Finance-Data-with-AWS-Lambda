# %%
import pandas as pd
import re
import datetime
import matplotlib.pyplot as plt
df=pd.read_csv('results.csv')
df.head()
# Out:
#    name  hour                   ts    max_high
# 0  BYND     9  05/14/2020 09:39:00  137.970001
# 1  BYND    10  05/14/2020 10:31:00  139.559998
# 2  BYND    11  05/14/2020 11:15:00  141.000000
# 3  BYND    12  05/14/2020 12:57:00  138.240005
# 4  BYND    13  05/14/2020 13:00:00  137.789902

# %% [markdown]
# ## Graph 1 : The Stock Price by Stocks
#
# The bar chart shows that SHOP has the highest price.

# %%
#the bar plot for the max_high by hours 
gp1 = df.groupby("name")['max_high'].mean().plot(kind='bar',title='The Maximum Price by Stocks')
gp1

# %%
#the scatterplot for the max_high by hours 
plt.scatter('hour', 'max_high', data = df )
plt.title('The Maximum Stock Price by Hours')
plt.xlabel('Hour')
plt.ylabel('Max Stock Price')
# Out:
# Text(0, 0.5, 'Max Stock Price')

# %% [markdown]
# ## Graph 2 : The Stock Price by Hours

# %% [markdown]
# The max_high is the highest ar 10am.

# %%
gp2 = df.groupby("hour")['max_high'].mean().plot(kind='bar',title='The Maximum Stock Price by Hours')
gp2

# %% [markdown]
# ## Graph 3 : How the highest stock price changes by hours for each stock on on 14th May, 2020?

# %%
gp5 = df.groupby('name').plot(x='hour', y='max_high',title='Change of Stock Price by Hour')
gp5
# Out:
# name
# BYND    AxesSubplot(0.125,0.125;0.775x0.755)
# DDOG    AxesSubplot(0.125,0.125;0.775x0.755)
# FB      AxesSubplot(0.125,0.125;0.775x0.755)
# NFLX    AxesSubplot(0.125,0.125;0.775x0.755)
# OKTA    AxesSubplot(0.125,0.125;0.775x0.755)
# PINS    AxesSubplot(0.125,0.125;0.775x0.755)
# SHOP    AxesSubplot(0.125,0.125;0.775x0.755)
# SNAP    AxesSubplot(0.125,0.125;0.775x0.755)
# SQ      AxesSubplot(0.125,0.125;0.775x0.755)
# TTD     AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %% [markdown]
# ## Graph 3 : How the highest stock price changes by company from 9am to 15pm on on 14th May, 2020?

# %%
for i in df[('hour')].unique():
    plt = df[df['hour'] == i]
    plt.plot('name', 'max_high',title = f'Change of stock by company {i}',color='green')
